# %%
# %pip install numpy
# %pip install pandas
# %pip install scikit-learn
# %pip install tensorflow
# %pip install matplotlib
# %pip install statsmodels
# %pip install keras

# %%
import math
import numpy as np
import pandas as pd
import datetime

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('SIDO.csv')

df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-01  270.435486  270.435486  270.435486  270.435486  202.735489
# 2018-01-02  272.916565  280.359741  265.473389  267.954437  200.875534
# 2018-01-03  267.954437  275.397613  265.473389  272.916565  204.595444
# 2018-01-04  275.397613  275.397613  270.435486  272.916565  204.595444
# 2018-01-05  272.916565  290.283966  270.435486  282.840790  212.035324
# ...                ...         ...         ...         ...         ...
# 2023-05-09  805.000000  805.000000  795.000000  800.000000  800.000000
# 2023-05-10  800.000000  805.000000  770.000000  775.000000  775.000000
# 2023-05-11  775.000000  775.000000  755.000000  775.000000  775.000000
# 2023-05-12  775.000000  785.000000  765.000000  775.000000  775.000000
# 2023-05-15  775.000000  785.000000  765.000000  775.000000  775.000000
#
#               Volume
# Date
# 2018-01-01         0
# 2018-01-02   9840956
# 2018-01-03  17716624
# 2018-01-04   2728068
# 2018-01-05  35399190
# ...              ...
# 2023-05-09  18328100
# 2023-05-10  37593900
# 2023-05-11  19482700
# 2023-05-12  22209000
# 2023-05-15   8562600
#
# [1340 rows x 6 columns]

# %%
#Visualize the data
plt.figure(figsize=(20,10))
plt.plot(df['Close'])
plt.title('SIDO Close Price History')
plt.xlabel('Jan. 01, 2012 - Dec. 17, 2019')
plt.ylabel('Close Price USD($)')
plt.legend(loc='upper left')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Create a new dataframe with only the 'Close column
data = df.filter(['Close'])
data.head()
# Out:
#                  Close
# Date
# 2018-01-01  270.435486
# 2018-01-02  267.954437
# 2018-01-03  272.916565
# 2018-01-04  272.916565
# 2018-01-05  282.840790

# %%
#Convert the dataframe to a numpy array
dataset = data.values

# %%
#Get the number of rows to train the model on
training_data_len = math.ceil(len(dataset)*.8)

# Scale the data
scaler = MinMaxScaler(feature_range=(0,1))#)
scaled_data = scaler.fit_transform(dataset)

# %%
# Create the training data set
train_data = scaled_data[0:training_data_len,:]

## Split the data into train and test
x_train = []
y_train = []

for i in range(60, len(train_data)):
  x_train.append(train_data[i-60:i,0])
  y_train.append(train_data[i,0])
  if i<=61:
    print(x_train)
    print(y_train)
    print()
print(len(x_train))
print(len(y_train))
# Out:
# [array([0.00317251, 0.        , 0.00634506, 0.00634506, 0.01903515,
#        0.01903515, 0.01586264, 0.01903515, 0.01903515, 0.01903515,
#        0.01903515, 0.02538021, 0.02538021, 0.02538021, 0.03489778,
#        0.03807029, 0.03807029, 0.03807029, 0.03807029, 0.04124285,
#        0.04758787, 0.05393293, 0.05076042, 0.06979557, 0.0856582 ,
#        0.0856582 , 0.07296808, 0.07296808, 0.07931314, 0.07614063,
#        0.07614063, 0.07614063, 0.09200323, 0.08883071, 0.08883071,
#        0.08883071, 0.09200323, 0.08883071, 0.08883071, 0.09517578,
#        0.08883071, 0.08883071, 0.08883071, 0.09200323, 0.09200323,
#        0.09200323, 0.08883071, 0.09200323, 0.09517578, 0.09517578,
#        0.09200323, 0.09200323, 0.09517578, 0.09200323, 0.08883071,
#        0.0856582 , 0.0856582 , 0.09200323, 0.0856582 , 0.09200323])]
# [0.08565820214965852]
#
# [array([0.00317251, 0.        , 0.00634506, 0.00634506, 0.01903515,
#        0.01903515, 0.01586264, 0.01903515, 0.01903515, 0.01903515,
#        0.01903515, 0.02538021, 0.02538021, 0.02538021, 0.03489778,
#        0.03807029, 0.03807029, 0.03807029, 0.03807029, 0.04124285,
#        0.04758787, 0.05393293, 0.05076042, 0.06979557, 0.0856582 ,
#        0.0856582 , 0.07296808, 0.07296808, 0.07931314, 0.07614063,
#        0.07614063, 0.07614063, 0.09200323, 0.08883071, 0.08883071,
#        0.08883071, 0.09200323, 0.08883071, 0.08883071, 0.09517578,
#        0.08883071, 0.08883071, 0.08883071, 0.09200323, 0.09200323,
#        0.09200323, 0.08883071, 0.09200323, 0.09517578, 0.09517578,
#        0.09200323, 0.09200323, 0.09517578, 0.09200323, 0.08883071,
#        0.0856582 , 0.0856582 , 0.09200323, 0.0856582 , 0.09200323]), array([0.        , 0.00634506, 0.00634506, 0.01903515, 0.01903515,
#        0.01586264, 0.01903515, 0.01903515, 0.01903515, 0.01903515,
#        0.02538021, 0.02538021, 0.02538021, 0.03489778, 0.03807029,
#        0.03807029, 0.03807029, 0.03807029, 0.04124285, 0.04758787,
#        0.05393293, 0.05076042, 0.06979557, 0.0856582 , 0.0856582 ,
#        0.07296808, 0.07296808, 0.07931314, 0.07614063, 0.07614063,
#        0.07614063, 0.09200323, 0.08883071, 0.08883071, 0.08883071,
#        0.09200323, 0.08883071, 0.08883071, 0.09517578, 0.08883071,
#        0.08883071, 0.08883071, 0.09200323, 0.09200323, 0.09200323,
#        0.08883071, 0.09200323, 0.09517578, 0.09517578, 0.09200323,
#        0.09200323, 0.09517578, 0.09200323, 0.08883071, 0.0856582 ,
#        0.0856582 , 0.09200323, 0.0856582 , 0.09200323, 0.0856582 ])]
# [0.08565820214965852, 0.08883071372485907]
#
# 1012
# 1012

# %%
#Conver the x_train and y_train to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
#Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# %%
# Build the LSTM model
model_lstm = Sequential()
model_lstm.add(LSTM(50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model_lstm.add(LSTM(50, return_sequences=False))
model_lstm.add(Dense(25))
model_lstm.add(Dense(1))

model_lstm.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model_lstm.fit(x_train, y_train,epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 7s 49ms/step - loss: 0.0219
# Epoch 2/100
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0015
# Epoch 3/100
# 32/32 [==============================] - 2s 51ms/step - loss: 9.7797e-04
# Epoch 4/100
# 32/32 [==============================] - 1s 46ms/step - loss: 9.3624e-04
# Epoch 5/100
# 32/32 [==============================] - 1s 43ms/step - loss: 9.3499e-04
# Epoch 6/100
# 32/32 [==============================] - 2s 51ms/step - loss: 9.1982e-04
# Epoch 7/100
# 32/32 [==============================] - 1s 45ms/step - loss: 9.4669e-04
# Epoch 8/100
# 32/32 [==============================] - 1s 46ms/step - loss: 9.4067e-04
# Epoch 9/100
# 32/32 [==============================] - 1s 46ms/step - loss: 8.8366e-04
# Epoch 10/100
# 32/32 [==============================] - 2s 48ms/step - loss: 9.5266e-04
# 32/32 [==============================] - 2s 49ms/step - loss: 2.9324e-04
# Epoch 81/100
# 32/32 [==============================] - 2s 55ms/step - loss: 2.7074e-04
# Epoch 82/100
# 32/32 [==============================] - 2s 53ms/step - loss: 3.0060e-04
# Epoch 83/100
# 32/32 [==============================] - 2s 50ms/step - loss: 2.7860e-04
# Epoch 84/100
# 32/32 [==============================] - 2s 56ms/step - loss: 2.7654e-04
# Epoch 85/100
# 32/32 [==============================] - 2s 52ms/step - loss: 3.3879e-04
# Epoch 86/100
# 32/32 [==============================] - 2s 49ms/step - loss: 2.5471e-04
# Epoch 87/100
# 32/32 [==============================] - 2s 56ms/step - loss: 2.6458e-04
# Epoch 88/100
# 32/32 [==============================] - 2s 58ms/step - loss: 2.4718e-04
# Epoch 89/100
# 32/32 [==============================] - 2s 52ms/step - loss: 2.5368e-04
# Epoch 90/100
# 32/32 [==============================] - 2s 58ms/step - loss: 2.7812e-04
# Epoch 91/100
# 32/32 [==============================] - 2s 68ms/step - loss: 2.7108e-04
# Epoch 92/100
# 32/32 [==============================] - 2s 67ms/step - loss: 2.7747e-04
# Epoch 93/100
# 32/32 [==============================] - 2s 63ms/step - loss: 3.0943e-04
# Epoch 94/100
# 32/32 [==============================] - 2s 65ms/step - loss: 2.7690e-04
# Epoch 95/100
# 32/32 [==============================] - 2s 68ms/step - loss: 2.6893e-04
# Epoch 96/100
# 32/32 [==============================] - 2s 64ms/step - loss: 2.6411e-04
# Epoch 97/100
# 32/32 [==============================] - 2s 67ms/step - loss: 2.7655e-04
# Epoch 98/100
# 32/32 [==============================] - 2s 64ms/step - loss: 3.2548e-04
# Epoch 99/100
# 32/32 [==============================] - 2s 71ms/step - loss: 2.5052e-04
# Epoch 100/100
# 32/32 [==============================] - 2s 66ms/step - loss: 2.5111e-04

# %%
## Create the testing data set
# Create a new array containing scaled vlues from index 1543 to 2003
test_data = scaled_data[training_data_len-60: , :]
#Create the data sets x_test and y_test
x_test = []
y_test = dataset[training_data_len:, : ]
for i in range(60, len(test_data)):
  x_test.append(test_data[i-60:i, 0])

# %%
# Convert the data to a numpy array
x_test = np.array(x_test)

# %%
# Reshape the data
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

# %%
# Get the model predicted price values
predictions = model_lstm.predict(x_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 9/9 [==============================] - 1s 19ms/step

# %%
# Plot the data
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
# Visualize the data
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price (RP)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])
plt.legend(['True', 'Val', 'Predictions'], loc = 'lower right')
plt.show()
# Out:
# C:\Users\dhori\AppData\Local\Temp\ipykernel_10712\2680035507.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
# Visualize the data
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price (Rp)', fontsize=18)
plt.plot(valid[['Close','Predictions']])
plt.legend(['True', 'Val', 'Predictions'], loc = 'lower right')
plt.show()

# %%
# # Get the MSE & RMSE
# mse = np.mean(predictions-y_test)**2
# rmse = np.sqrt(np.mean(predictions-y_test)**2)


# Get the MSE & RMSE
mse = np.mean(predictions-y_test)**2
rmse = np.sqrt(np.mean(predictions-y_test)**2)
mape = np.mean((np.abs(predictions - y_test) / y_test) * 100)

print('MAPE : %.5f' % mape)
print('MSE : %.5f' % mse)
print('RMSE : %.5f' % rmse)
# Out:
# MAPE : 1.28765
# MSE : 0.25677
# RMSE : 0.50672
